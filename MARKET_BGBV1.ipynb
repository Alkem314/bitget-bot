# %%
import ta
import time
import math
import pprint
import asyncio
import datetime
import itertools
import pandas as pd
import SecretConfig
import ccxt.pro as ccxt
from IPython.display import clear_output

# %%
# §§§§§§§§§§

await exchange.close()

# §§§§§§§§§§

# %%
exchange = ccxt.bitget({
    "apiKey":SecretConfig.APIKey,
    "secret":SecretConfig.SecretKey,
    'password': SecretConfig.Passphrase,
    "options": {'defaultType': 'swap', 'adjustForTimeDifference' : True},
    "timeout": 60000,
    "enableRateLimit": True,
})

# %%
# LIVE PRICE ET MARKETS

async def live_prices() :

    global last_20
    global tickers
    global swap_markets
  
    tickers = await exchange.fetch_tickers()

    await asyncio.sleep(0.005)

    timestamp = list(tickers.values())[0]['timestamp']
    index = [datetime.datetime.fromtimestamp(timestamp/1000).replace(microsecond=0)]

    data = {}

    for symbol, ticker in tickers.items():

        data[symbol +  " last"] = [ticker['last']]
        data[symbol +  " ask"] = [ticker['ask']]
        data[symbol +  " bid"] = [ticker['bid']]

    last_prices = pd.DataFrame(data, index=index)
    last_20 = pd.concat([last_20, last_prices])
    last_20 = last_20.tail( wind_EMA2 + wind_Var_EMA2 + wind_Div_EMA1_2 + wind_EMA2 +30)

    markets = await exchange.load_markets()

    await asyncio.sleep(0.005)

    swap_markets = {symbol: market for symbol, market in markets.items() if market['swap']}

# %%
# CALCUL DES INDICATEURS TECHNIQUES

async def indicators_calculation() :
    
    global data1
    global data2
    global data3 
    global data4 
    global data5
    global data6
    global data7
    global data8

    global top_10_values

    global fulldata
       
    fulldata_row = pd.DataFrame()

    index = [last_20.index[-1]] 

    data_row_step1 = pd.DataFrame({symbol + suffix:
                                   [last_20[symbol + " last"].iloc[-1]] if suffix == " last" else 
                                   [last_20[symbol + " ask"].iloc[-1]] if suffix == " ask" else 
                                   [last_20[symbol + " bid"].iloc[-1]] if suffix == " bid" else
                                   [(last_20[symbol + " last"].iloc[-1]) - (last_20[symbol + " last"].iloc[- wind_Var_Price])/
                                    last_20[symbol + " last"].iloc[- wind_Var_Price] * 100] if suffix == ' Var Last Price' and len(last_20) > wind_Var_Price else
                                     [ta.trend.ema_indicator(last_20[symbol + ' last'], window= wind_EMA1).iloc[-1]] if suffix == ' EMA_1' and len(last_20) > wind_EMA1 else
                                     [ta.trend.ema_indicator(last_20[symbol + ' last'], window= wind_EMA2).iloc[-1]] if suffix == ' EMA_2' and len(last_20) > wind_EMA2 else
                                     [ta.trend.ema_indicator(last_20[symbol + ' last'], window= wind_EMA3).iloc[-1]] if suffix == ' EMA_3' and len(last_20) > wind_EMA3 else
                                     [None] for symbol, ticker in tickers.items() for suffix in 
                                     [" last", " ask", " bid", ' Var Last Price', ' EMA_1', ' EMA_2', ' EMA_3']}, index=index)

                                
    data_row_step1 = data_row_step1.apply(pd.to_numeric)
    data1 = pd.concat([data1, data_row_step1])
    data1 = data1.tail(wind_Var_EMA1 + wind_Var_EMA2 + 30)
    # await asyncio.sleep(0.01)

   

    data_row_step2 = pd.DataFrame({symbol + suffix:
                                   (data1[symbol + " Var Last Price"].iloc[-1])**2 if suffix == ' Var Carre Last Price' and len(last_20) > wind_Var_Price else
                                   ((data1[symbol + ' EMA_1'].iloc[-1] - data1[symbol + ' EMA_1'].iloc[- wind_Var_EMA1]) /
                                    data1[symbol + ' EMA_1'].iloc[- wind_Var_EMA1]) * 100  if suffix == ' Var EMA_1' and len(last_20) > wind_EMA1 + wind_Var_EMA1  else
                                    ((data1[symbol + ' EMA_2'].iloc[-1] - data1[symbol + ' EMA_2'].iloc[- wind_Var_EMA2]) /
                                     data1[symbol + ' EMA_2'].iloc[- wind_Var_EMA2]) * 100  if suffix == ' Var EMA_2' and len(last_20) > wind_EMA2 + wind_Var_EMA2 else
                                     (data1[symbol + " last"].iloc[- 1] - data1[symbol + ' EMA_1'].iloc[-1]) ** 2 if suffix == ' Diff Carre Price_EMA_1' and len(last_20) > wind_EMA1 else
                                     (data1[symbol + ' EMA_1'].iloc[- 1] - data1[symbol + ' EMA_2'].iloc[-1]) ** 2 if suffix == ' Diff Carre EMA_1_2' and len(last_20) > wind_EMA2 else
                                     [None] for symbol, ticker in tickers.items() for suffix in 
                                     [' Var Carre Last Price', ' Var EMA_1', ' Var EMA_2', ' Diff Carre Price_EMA_1', ' Diff Carre EMA_1_2']}, index=index)
    
    data_row_step2 = data_row_step2.apply(pd.to_numeric)
    data2 = pd.concat([data2, data_row_step2])
    data2 = data2.tail(wind_Div_Price_EMA1 + wind_Div_EMA1_2 + 5)
    # await asyncio.sleep(0.01)
    
    data_row_step3 = pd.DataFrame({symbol+ suffix:
                                   ((data2[symbol + ' Diff Carre Price_EMA_1'].iloc[-1] - data2[symbol + ' Diff Carre Price_EMA_1'].iloc[- wind_Div_Price_EMA1]) /
                                    data2[symbol + ' Diff Carre Price_EMA_1'].iloc[- wind_Div_Price_EMA1]) * 100  if suffix == ' Divergence Price_EMA_1' and len(last_20) > wind_EMA1 + wind_Div_Price_EMA1 and data2[symbol + ' Diff Carre Price_EMA_1'].iloc[- wind_Div_Price_EMA1] != 0 else
                                    ((data2[symbol + ' Diff Carre EMA_1_2'].iloc[-1] - data2[symbol + ' Diff Carre EMA_1_2'].iloc[- wind_Div_EMA1_2]) /
                                    data2[symbol + ' Diff Carre EMA_1_2'].iloc[- wind_Div_EMA1_2]) * 100  if suffix == ' Divergence EMA_1_2' and len(last_20) > wind_EMA2 + wind_Div_EMA1_2 and data2[symbol + ' Diff Carre EMA_1_2'].iloc[- wind_Div_EMA1_2] != 0 else
                                    [None] for symbol, ticker in tickers.items() for suffix in 
                                    [' Divergence Price_EMA_1', ' Divergence EMA_1_2']}, index=index)
    
    data_row_step3 = data_row_step3.apply(pd.to_numeric)
    data3 = pd.concat([data3, data_row_step3])
    data3 = data3.tail(wind_Div_Moy_Price_EMA1 + wind_Div_Moy_EMA1_2 + 5)
    # await asyncio.sleep(0.01)

    data_row_step4 = pd.DataFrame({symbol + suffix:
                                   ta.trend.ema_indicator(data3[symbol + ' Divergence Price_EMA_1'], window= wind_Div_Moy_Price_EMA1).iloc[-1] if suffix == ' Divergence Moyen Price_EMA_1' and len(last_20) > wind_EMA1 + wind_Div_Price_EMA1 + wind_Div_Moy_Price_EMA1 else 
                                   ta.trend.ema_indicator(data3[symbol + ' Divergence EMA_1_2'], window= wind_Div_Moy_EMA1_2).iloc[-1] if suffix == ' Divergence Moyen EMA_1_2' and len(last_20) > wind_EMA2 + wind_Div_EMA1_2 + wind_Div_Moy_EMA1_2  else 
                                   [None] for symbol, ticker in tickers.items() for suffix in 
                                   [' Divergence Moyen Price_EMA_1', ' Divergence Moyen EMA_1_2']}, index=index)
    
    data_row_step4 = data_row_step4.apply(pd.to_numeric)
    data4 = pd.concat([data4, data_row_step4])
    data4 = data4.tail(wind_Div_Price_EMA1 + wind_Div_Moy_Price_EMA1 + wind_Div_EMA1_2 + wind_Div_Moy_EMA1_2 + 30)
    # await asyncio.sleep(0.01)

    data_row_step5 = pd.DataFrame({symbol + suffix:
                                   data4[symbol + ' Divergence Moyen Price_EMA_1'].iloc[-1] > 35000 and data4[symbol + ' Divergence Moyen EMA_1_2'].iloc[-1]  > 15000 if suffix == ' Condition'
                                   and len(last_20) > wind_EMA2 + wind_Div_EMA1_2 + wind_Div_Moy_EMA1_2 else
                                   [None] for symbol, ticker in tickers.items() for suffix in 
                                   [' Condition']}, index=index)
    
    # data_row_step5 = data_row_step5.apply(pd.to_numeric)
    data5 = pd.concat([data5, data_row_step5])
    # data5 = data5.apply(pd.to_numeric)
    data5 = data5.tail(5)
    # clear_output(wait=True)
    # display(data5.tail(2))
    # await asyncio.sleep(0.01)


    top_div = {}
    top_10_values = {}

    for symbol, ticker in tickers.items():
        if len(last_20) > wind_EMA1 + wind_Div_Price_EMA1:
            if data3[symbol + ' Divergence Price_EMA_1'].iloc[-1] > div_min_top:
                top_div[symbol] = (data3[symbol + ' Divergence Price_EMA_1'].iloc[-1], ticker['info']['symbol'])

    if top_div:
        top_10_values = dict(sorted(top_div.items(), key=lambda item: item[1][0], reverse=True)[:10])

    # display(f'top is : {top_10_values}')
  
    data_row_step6 = pd.DataFrame({symbol + suffix:
                                   1 if suffix == ' Top_10' and top_10_values is not None and symbol in top_10_values.keys() and len(last_20) > wind_EMA1 + wind_Div_Price_EMA1 else 
                                   [None] for symbol, ticker in tickers.items() for suffix in 
                                   [' Top_10']}, index=index)
    
    data_row_step6 = data_row_step6.apply(pd.to_numeric)
    data6 = pd.concat([data6, data_row_step6])
    data6 = data6.tail(occur_wind)
    # clear_output(wait=True)
    
    '''if len(last_20) > wind_EMA1 + wind_Div_Price_EMA1 :
        
        display(data6.tail(2))'''
    # await asyncio.sleep(0.01)

    data_row_step7 = pd.DataFrame({symbol + suffix: 
                                   data6[symbol + ' Top_10'].sum() if suffix == ' Occur' and len(fulldata) > wind_EMA1 + wind_Div_Price_EMA1 + wind_Div_Moy_Price_EMA1 + occur_wind + 1 else 
                                   [None] for symbol, ticker in tickers.items() for suffix in 
                                   [' Occur']}, index=index)
    data_row_step7 = data_row_step7.apply(pd.to_numeric)
    data7 = pd.concat([data7, data_row_step7])
    data7 = data7.tail(2)
    '''if len(fulldata) > wind_EMA1 + wind_Div_Price_EMA1 + wind_Div_Moy_Price_EMA1 + occur_wind :
        display(data7)'''
    # await asyncio.sleep(0.01)

    data_row_step8 = pd.DataFrame({symbol+ suffix:
                                   "open_long" if suffix == ' Tradable' and data7[symbol +' Occur'].iloc[-1] is not None and data7[symbol +' Occur'].iloc[-1] >=
                                     min_occur and data5[symbol + ' Condition'].iloc[-1] and
                                   data1[symbol + ' Var Last Price'].iloc[-1] > 0 and data1[symbol + " last"].iloc[-1] >
                                     data1[symbol + ' EMA_1'].iloc[-1] > data1[symbol + ' EMA_2'].iloc[-1] > data1[symbol + ' EMA_3'].iloc[-1] and len(fulldata) >
                                       wind_EMA1 + wind_EMA2 + wind_EMA3 + wind_Div_EMA1_2 + wind_Div_Moy_EMA1_2 + occur_wind else
                                   "open_short" if suffix == ' Tradable' and data7[symbol +' Occur'].iloc[-1] is not None and data7[symbol +' Occur'].iloc[-1] >=
                                     min_occur and data5[symbol + ' Condition'].iloc[-1] and
                                   data1[symbol + ' Var Last Price'].iloc[-1] < 0 and data1[symbol + " last"].iloc[-1] <
                                     data1[symbol + ' EMA_1'].iloc[-1] < data1[symbol + ' EMA_2'].iloc[-1] < data1[symbol + ' EMA_3'].iloc[-1] and len(fulldata) >
                                       wind_EMA1 + wind_EMA2 + wind_EMA3 + wind_Div_EMA1_2 + wind_Div_Moy_EMA1_2 + occur_wind else 
                                   [None] for symbol, ticker in tickers.items() for suffix in 
                                   [' Tradable']}, index=index) 
    data8 = pd.concat([data8, data_row_step8])
    data8 = data8.tail(2)
    opennbr = data8.iloc[-1].value_counts()
    display(opennbr)
    '''if len(fulldata) > wind_EMA1 + wind_EMA2 + wind_Div_EMA1_2 + wind_Div_Moy_EMA1_2 + occur_wind :
        display(data8)'''
    # await asyncio.sleep(0.01)


    fulldata_row = pd.concat([data_row_step1, data_row_step2, data_row_step3, data_row_step4, data_row_step5, data_row_step6, data_row_step7, data_row_step8], axis=1)
    fulldata_row = fulldata_row.apply(pd.to_numeric, errors='ignore')
    fulldata_row =fulldata_row.sort_index(axis=1)
    fulldata = pd.concat([fulldata, fulldata_row])
    fulldata = fulldata.tail(wind_EMA1 + wind_EMA2 + wind_EMA3 + wind_Div_EMA1_2 + wind_Div_Moy_EMA1_2 + occur_wind + wind_EMA2)
    # clear_output(wait=True)
    # display(data_row_step8)
    # await asyncio.sleep(0.01)

# %%
# MISE A JOUR DE LA BALANCE

async def refresh_balance() :

    global balance
    global free_balance
    global open_PNL
    global alertnbr
    global alert_df

    try :

        balance_data = await exchange.fetch_balance()

        await asyncio.sleep(0.005)

        balance = float(balance_data['info'][0]['available'])
        free_balance = float(balance_data['free']['USDT'])
        open_PNL = float(balance_data['info'][0]['unrealizedPL'])
    
    except Exception as e:
        
        alert = {'alert': str(e)}
        alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} balance'])
        alert_df = pd.concat([alert_df, alert_data])
        alertnbr += 1

    if balance < 385 :

        display("Balance is less than 385, stopping the program.")
        exit()

    # display(f'Balance is {balance}')
    # await asyncio.sleep(0.01)

# %%
# CHECK EXISTING Order & SL V3 test par list entière TESTE COMPRESSION SL 4

async def config_strikerV3() :

    global df_open_trade_info
    global df_closed_trade_info
    global nbr_open_trade
    global trade_nb
    global nbr_max_trade
    global trail_stop
    global alertnbr
    global alert_df

    if not df_open_trade_info.empty:

        response_pos = None
        response_ord = None
        
        try : 

            response_pos = await exchange.fetch_positions(df_open_trade_info.index)

        except Exception as e: 
                            
            alert = {'alert': f'{e}'}
            alert_data = pd.DataFrame(alert, index=[f'GLOBAL WARNING POSITION {alertnbr} conf 22'])
            alert_df = pd.concat([alert_df, alert_data])
            alertnbr += 1
            
        if response_pos :

            for symbol in df_open_trade_info.index :

                pos_list = [pos for pos in response_pos if "info" in pos and "symbol" in pos["info"] and pos["info"]["symbol"] == symbol 
                    and 'unrealizedPnl' in pos]

                if pos_list:

                    pos = next(iter(pos_list))
                    df_open_trade_info.loc[symbol, 'actual_pnl'] = pos['unrealizedPnl']

                    if df_open_trade_info.loc[symbol, 'status'] == "open" and df_open_trade_info.loc[symbol, 'sl_side'] == "close_long" :
                        
                        if (fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_1" ].iloc[-1] > fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_2" ].iloc[-1] >
                            fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_3" ].iloc[-1] and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_max" 
                            and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_rush" and df_open_trade_info.loc[symbol, 'sl_max_ref'] < fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1]
                            and df_open_trade_info.loc[symbol, 'sl_mid_ref'] < fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1]) :
                             
                             df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to max"
                             display(f"{symbol} sl version set to max")
                             df_open_trade_info.loc[symbol, 'sl_max_ref'] = float(fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1])

                        elif (fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_2" ].iloc[-1] > fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_1" ].iloc[-1] >
                            fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_3" ].iloc[-1] and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_mid" 
                            and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_rush" and df_open_trade_info.loc[symbol, 'sl_mid_ref'] < fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1]) :
                             
                             df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to mid"
                             display(f"{symbol} sl version set to mid")
                             df_open_trade_info.loc[symbol, 'sl_mid_ref'] = float(fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1])

                        elif (fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_3" ].iloc[-1] > fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_2" ].iloc[-1] >
                            fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_1" ].iloc[-1] and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_low"
                            and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_critical") :
                             
                             df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to low"
                             display(f"{symbol} sl version set to low")

                        if pos['unrealizedPnl']  < 0 and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_critical" :
                             
                             df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to critical"
                             display(f"{symbol} sl version set to critical")

                        if pos['unrealizedPnl']  > 0.03 and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_rush": 
                            
                            df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to rush"
                            display(f"{symbol} sl version set to rush")

                    elif df_open_trade_info.loc[symbol, 'status'] == "open" and df_open_trade_info.loc[symbol, 'sl_side'] == "close_short":
                        
                        if (fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_3" ].iloc[-1] > fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_2" ].iloc[-1] >
                            fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_1" ].iloc[-1] and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_max"
                            and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_rush" and df_open_trade_info.loc[symbol, 'sl_max_ref'] > fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1]
                            and df_open_trade_info.loc[symbol, 'sl_mid_ref'] > fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1]) :
                             
                             df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to max"
                             display(f"{symbol} sl version set to max")
                             df_open_trade_info.loc[symbol, 'sl_max_ref'] = float(fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1])

                        elif (fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_3" ].iloc[-1] > fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_1" ].iloc[-1] >
                            fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_2" ].iloc[-1] and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_mid"
                            and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_rush" and df_open_trade_info.loc[symbol, 'sl_mid_ref'] > fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1]) :
                             
                             df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to mid"
                             display(f"{symbol} sl version set to mid")
                             df_open_trade_info.loc[symbol, 'sl_mid_ref'] = float(fulldata[df_open_trade_info.loc[symbol, 'sym'] + " last" ].iloc[-1]) 

                        elif (fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_1" ].iloc[-1] > fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_2" ].iloc[-1] >
                            fulldata[df_open_trade_info.loc[symbol, 'sym'] + " EMA_3" ].iloc[-1] and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_low"
                            and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_critical") :
                             
                             df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to low"
                             display(f"{symbol} sl version set to low")

                        if pos['unrealizedPnl']  < 0  and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_critical" :
                             
                             df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to critical"
                             display(f"{symbol} sl version set to critical")

                        if pos['unrealizedPnl']  > 0.03 and df_open_trade_info.loc[symbol, 'sl_version'] != "sl_rush": 
                            
                            df_open_trade_info.loc[symbol, 'sl_version'] = "set sl to rush"
                            display(f"{symbol} sl version set to rush")

                    if df_open_trade_info.loc[symbol, 'status'] == "starting" or df_open_trade_info.loc[symbol, 'status'] == "set_new_sl" :

                        try :

                            params = {"stop" : True, "planType" : "track_plan"}
                            response_ord= await exchange.fetch_open_orders(symbol, params=params)
                            await asyncio.sleep(0.01)

                            if any('info' in resp and 'side' in resp['info'] and ("close_long" in resp['info']['side'] or "close_short" in resp['info']['side']) 
                                   and "id" in resp and resp["id"] == df_open_trade_info.loc[symbol, 'sl_id'] for resp in response_ord):
                                
                                df_open_trade_info.loc[symbol, 'status'] = "open"
                                
                            else :
                    
                                df_open_trade_info.loc[symbol, 'status'] = "SL WARNING" 

                        except Exception as e: 
                            
                            alert = {'alert': f'{e}'}
                            alert_data = pd.DataFrame(alert, index=[f'GLOBAL WARNING POSITION {alertnbr} {symbol}'])
                            alert_df = pd.concat([alert_df, alert_data])
                            alertnbr += 1
                            if df_open_trade_info.loc[symbol, 'status'] != "set_new_sl" :
                    
                                df_open_trade_info.loc[symbol, 'status'] = "set_new_sl" 

                            else :
                    
                                df_open_trade_info.loc[symbol, 'status'] = "SL WARNING"

                else : 

                    if df_open_trade_info.loc[symbol, 'status'] == "open" :

                        df_open_trade_info.loc[symbol, 'status'] = "first_closing"

                    elif df_open_trade_info.loc[symbol, 'status'] == "first_closing" :             

                            df_open_trade_info.loc[symbol, 'status'] = "close" 

        else :

            for symbol in df_open_trade_info.index :

                if df_open_trade_info.loc[symbol, 'status'] == "open" :

                        df_open_trade_info.loc[symbol, 'status'] = "first_closing"

                elif df_open_trade_info.loc[symbol, 'status'] == "first_closing" :             

                        df_open_trade_info.loc[symbol, 'status'] = "close"

# %%
async def cleaner() :

    global df_open_trade_info
    global df_closed_trade_info
    global nbr_open_trade
    global trade_nb
    global nbr_max_trade
    global trail_stop
    global alertnbr
    global alert_df

    if not df_open_trade_info.empty:

        for symbol in df_open_trade_info.index :

            if (df_open_trade_info.loc[symbol, 'status'] == "close" or df_open_trade_info.loc[symbol, 'status'] == "cancel" 
                or df_open_trade_info.loc[symbol, 'status'] == "bad-config" or df_open_trade_info.loc[symbol, 'status'] == "SL WARNING CLOSING"):

                if (df_open_trade_info.loc[symbol, 'sl_version'] == "set sl to high" or df_open_trade_info.loc[symbol, 'sl_version'] == "set sl to mid"
                    or df_open_trade_info.loc[symbol, 'sl_version'] == "set sl to low" or df_open_trade_info.loc[symbol, 'sl_version'] == "set sl to critical") :

                    try : 
                        params = {"stop" : True, "planType" : "track_plan"}

                        await exchange.cancel_order(df_open_trade_info["sl_id"].loc[symbol], symbol, params= params)
                    
                    except Exception as e :
                            
                        alert = {'alert': str(e)}
                        alert_data = pd.DataFrame(alert, index=[f'Not alert_nbr {alertnbr} cleaner1'])
                        alert_df = pd.concat([alert_df, alert_data])
                        alertnbr += 1

                    try : 
                        params = {"stop" : True, "planType" : "track_plan"}

                        await exchange.cancel_order(df_open_trade_info["new_sl_id"].loc[symbol], symbol, params= params)
                    
                    except Exception as e :
                            
                        alert = {'alert': str(e)}
                        alert_data = pd.DataFrame(alert, index=[f'Not alert_nbr {alertnbr} cleaner2'])
                        alert_df = pd.concat([alert_df, alert_data])
                        alertnbr += 1
                
                df_closed_trade_info = pd.concat([df_closed_trade_info, df_open_trade_info.loc[[symbol]]])
                
                df_open_trade_info = df_open_trade_info.drop(symbol)

                nbr_open_trade -= 1
            
                await asyncio.sleep(0.005)

# %%
# MISE A JOUR SL 

async def sl_loader():

    global df_open_trade_info
    global df_closed_trade_info
    global nbr_open_trade
    global trade_nb
    global nbr_max_trade
    global trail_stop
    global alertnbr
    global alert_df
    global rangeRate_max
    global rangeRate_mid
    global rangeRate_low
    global rangeRate_critical
    global rangeRate_rush

    if not df_open_trade_info.empty:

        for symbol in df_open_trade_info.index:

            list_change_sl = []

            if (df_open_trade_info.loc[symbol, 'status'] == "set_new_sl" or df_open_trade_info.loc[symbol, 'status'] == "SL WARNING" 
                or df_open_trade_info.loc[symbol, 'sl_version'] == "set sl to max" ):

                list_change_sl = []

                try :

                    new_sl_type = "sl_max" 
                
                    list_change_sl ={
                        'symbol': symbol,
                        'side': df_open_trade_info.loc[symbol, 'sl_side'],
                        'size': df_open_trade_info.loc[symbol, 'size'],
                        "marginCoin": "USDT",
                        "triggerType":"market_price",
                        "reduceOnly" : True,
                        "leverage": "1",
                        "planType" : "track_plan",
                        "timeInForce":"normal",
                        "rangeRate" : rangeRate_max,
                        }
                
                    await asyncio.sleep(0.005)
                
                except Exception as e :
                            
                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'Not alert_nbr {alertnbr} sl1'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1

                    if df_open_trade_info.loc[symbol, 'status'] != "SL WARNING" :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING"

                    else :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING 2"

            elif df_open_trade_info.loc[symbol, 'sl_version'] == "set sl to mid" :
                
                list_change_sl = []

                try :

                    new_sl_type = "sl_mid" 
                
                    list_change_sl ={
                        'symbol': symbol,
                        'side': df_open_trade_info.loc[symbol, 'sl_side'],
                        'size': df_open_trade_info.loc[symbol, 'size'],
                        "marginCoin": "USDT",
                        "triggerType":"market_price",
                        "reduceOnly" : True,
                        "leverage": "1",
                        "planType" : "track_plan",
                        "timeInForce":"normal",
                        "rangeRate" : rangeRate_mid,
                        }
                
                    await asyncio.sleep(0.005)
                
                except Exception as e :
                            
                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'Not alert_nbr {alertnbr} sl2'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1

                    if df_open_trade_info.loc[symbol, 'status'] != "SL WARNING" :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING"

                    else :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING 2"

            elif df_open_trade_info.loc[symbol, 'sl_version'] == "set sl to low" :  

                list_change_sl = []   

                try :

                    new_sl_type = "sl_low" 
                
                    list_change_sl ={
                        'symbol': symbol,
                        'side': df_open_trade_info.loc[symbol, 'sl_side'],
                        'size': df_open_trade_info.loc[symbol, 'size'],
                        "marginCoin": "USDT",
                        "triggerType":"market_price",
                        "reduceOnly" : True,
                        "leverage": "1",
                        "planType" : "track_plan",
                        "timeInForce":"normal",
                        "rangeRate" : rangeRate_low,
                        }
                
                    await asyncio.sleep(0.005)
                
                except Exception as e :
                            
                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'Not alert_nbr {alertnbr} sl2'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1

                    if df_open_trade_info.loc[symbol, 'status'] != "SL WARNING" :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING"

                    else :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING 2"

            elif df_open_trade_info.loc[symbol, 'sl_version'] == "set sl to critical" :  

                list_change_sl = []   

                try :

                    new_sl_type = "sl_critical" 
                
                    list_change_sl ={
                        'symbol': symbol,
                        'side': df_open_trade_info.loc[symbol, 'sl_side'],
                        'size': df_open_trade_info.loc[symbol, 'size'],
                        "marginCoin": "USDT",
                        "triggerType":"market_price",
                        "reduceOnly" : True,
                        "leverage": "1",
                        "planType" : "track_plan",
                        "timeInForce":"normal",
                        "rangeRate" : rangeRate_critical,
                        }
                
                    await asyncio.sleep(0.005)
                
                except Exception as e :
                            
                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'Not alert_nbr {alertnbr} sl2'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1

                    if df_open_trade_info.loc[symbol, 'status'] != "SL WARNING" :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING"

                    else :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING 2"

            elif df_open_trade_info.loc[symbol, 'sl_version'] == "set sl to rush" :  

                list_change_sl = []   

                try :

                    new_sl_type = "sl_rush" 
                
                    list_change_sl ={
                        'symbol': symbol,
                        'side': df_open_trade_info.loc[symbol, 'sl_side'],
                        'size': df_open_trade_info.loc[symbol, 'size'],
                        "marginCoin": "USDT",
                        "triggerType":"market_price",
                        "reduceOnly" : True,
                        "leverage": "1",
                        "planType" : "track_plan",
                        "timeInForce":"normal",
                        "rangeRate" : rangeRate_rush,
                        }
                
                    await asyncio.sleep(0.005)
                
                except Exception as e :
                            
                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'Not alert_nbr {alertnbr} sl2'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1

                    if df_open_trade_info.loc[symbol, 'status'] != "SL WARNING" :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING"

                    else :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING 2"

            if list_change_sl : 

                try :
                        
                    new_sl = await exchange.privateMixPostPlanPlaceTrailStop(list_change_sl)

                    await asyncio.sleep(0.01)

                except Exception as e :
                            
                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} sl4'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1

                    if df_open_trade_info.loc[symbol, 'status'] != "SL WARNING" :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING"

                    else :
                    
                        df_open_trade_info.loc[symbol, 'status'] = "SL WARNING 2"

                if new_sl and new_sl['msg'] == 'success' and 'orderId' in new_sl['data']:

                    df_open_trade_info.loc[symbol, "new_sl_id"] = new_sl['data']['orderId']

                    params = {"stop" : True, "planType" : "track_plan"}

                    respord = await exchange.fetch_open_orders(symbol, params= params)

                    if any("id" in resp and resp['id'] == df_open_trade_info.loc[symbol, 'sl_id'] and
                        'info' in resp and 'side' in resp['info'] and ("close_long" in resp['info']['side'] or "close_short" in resp['info']['side']) for resp in respord) :

                        try :
                                
                            params = {"stop" : True, "planType" : "track_plan"}

                            await exchange.cancel_order(df_open_trade_info["sl_id"].loc[symbol], symbol, params= params)

                            await asyncio.sleep(0.005)

                            df_open_trade_info.loc[symbol, 'sl_id'] = df_open_trade_info.loc[symbol, 'new_sl_id']

                            df_open_trade_info.loc[symbol, 'sl_version'] = new_sl_type

                        except Exception as e :
                            
                            alert = {'alert': str(e)}
                            alert_data = pd.DataFrame(alert, index=[f'Not alert_nbr {alertnbr} sl3'])
                            alert_df = pd.concat([alert_df, alert_data])
                            alertnbr += 1
                                    
                            df_open_trade_info.loc[symbol, 'sl_id'] = df_open_trade_info.loc[symbol, 'new_sl_id']

                            if df_open_trade_info.loc[symbol, 'status'] != "first_closing" :
                                
                                df_open_trade_info.loc[symbol, 'status'] = "SL WARNING CLOSING"

                            else :

                                params = {"stop" : True, "planType" : "track_plan"}

                                await exchange.cancel_order(df_open_trade_info['new_sl_id'].loc[symbol], symbol, params= params)

                                # df_open_trade_info.loc[symbol, 'status'] = "close"    verifié si il est activé le first closing n'a pas sont deuxième cheking ????

                                alert = {'alert': f'trade {symbol} Forced SL closing'}
                                alert_data = pd.DataFrame(alert, index=[f'Not alert_nbr {alertnbr} sl32'])
                                alert_df = pd.concat([alert_df, alert_data])
                                alertnbr += 1
                                
                                display(f'trade {symbol} Forced SL closing')

                else : df_open_trade_info.loc[symbol, 'status'] = "SL WARNING derniere ligne sl loader"

# %%
# OUVERTURE DES ORDRES

async def trade_opener() :

    global df_open_trade_info
    global df_closed_trade_info
    global nbr_open_trade
    global trade_nb
    global nbr_max_trade
    global trail_stop
    global alertnbr
    global alert_df

    if (top_10_values is not None and len(fulldata) > wind_EMA1 + wind_EMA2 + wind_Div_EMA1_2 + wind_Div_Moy_EMA1_2 + occur_wind 
        and not data8.empty and data8.iloc[-1].notnull().any() and free_balance > 50 and nbr_open_trade <= 30) :

        # display(f'for trade opener nbr_open_trade is {nbr_open_trade}')

        # for symbol, ticker in tickers.items() :
        for symbol in top_10_values.keys():
       
            trade = []

            # pprint.pprint(f'tentative pour {symbol}')
            
            if top_10_values[symbol][1] not in df_open_trade_info.index and data8[symbol + ' Tradable'].iloc[-1] == 'open_long' :

                # pprint.pprint(f'tentative data8 pour {symbol}')

                try :

                    trade = {
                        'symbol': top_10_values[symbol][1],
                        'side': 'open_long',
                        'size': exchange.amount_to_precision(symbol, round(balance * (0.9/nbr_max_trade), 2) / fulldata[symbol + ' last'].iloc[-1]),
                        'params' : {
                            "marginCoin": "USDT",
                            'side': 'open_long',
                            'force': "post_only",
                            "leverage": "1"}
                        }
                    
                    sl_trade = {
                        'symbol': top_10_values[symbol][1],
                        'side': 'close_long',
                        'size': exchange.amount_to_precision(symbol, round(balance * (0.9/nbr_max_trade), 2) / fulldata[symbol + ' last'].iloc[-1]),
                        "marginCoin": "USDT",
                        "triggerType":"market_price",
                        "reduceOnly" : True,
                        "leverage": "1",
                        'side': 'close_long',
                        "planType" : "track_plan",
                        "timeInForce":"normal",
                        "rangeRate" : 0.2,
                        }
                        
                
                except Exception as e:
                                     
                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} open1 {symbol}'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1
                    continue

                
                id = None
                sl_id = None
                response_create_sl = None
                response_open_ord = None
                create_ord = None

                try :
                    
                    response_create_sl = await exchange.privateMixPostPlanPlaceTrailStop(sl_trade)
                
                    await asyncio.sleep(0.01)

                except Exception as e:

                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} open7 {symbol}'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1
                    continue

                if response_create_sl ['msg'] == 'success' and 'orderId' in response_create_sl['data']:
                        
                    sl_id = response_create_sl['data']['orderId']
                        
                    await asyncio.sleep(0.01)

                    params = {"stop" : True, "planType" : "track_plan"}
                    response_open_ord = await exchange.fetch_open_orders(symbol, params= params)
                    await asyncio.sleep(0.01)
                    # response_open_ord.extend(await exchange.fetch_open_orders(symbol))
                    # await asyncio.sleep(0.01)

                    if len(response_open_ord) == 1 and any("id" in resp and resp["id"] == sl_id for resp in response_open_ord) : 

                        try :
                    
                            create_ord= await exchange.create_market_order(trade['symbol'], trade['side'], trade['size'], trade['params'])
                
                            await asyncio.sleep(0.01)

                        except Exception as e:
                                     
                            alert = {'alert': str(e)}
                            alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} open8 {symbol}'])
                            alert_df = pd.concat([alert_df, alert_data])
                            alertnbr += 1

                            try :

                                params = {"stop" : True, "planType" : "track_plan"}
                                await exchange.cancel_order(sl_id, symbol, params= params)
                                # await exchange.cancel_order(sl_id, symbol)

                            except Exception as e:

                                alert = {'alert': str(e)}
                                alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} open9 {symbol}'])
                                alert_df = pd.concat([alert_df, alert_data])
                                alertnbr += 1

                        if create_ord is not None :
                            
                            if "id" in create_ord : 
                        
                                id = create_ord['id']

                                await asyncio.sleep(0.005)

                                df_trade_row = pd.DataFrame({
                                    'symbol': [trade['symbol']],
                                    'size' : [float(trade['size'])],
                                    'side': [trade['side']],
                                    'opening_price': [fulldata[symbol + ' last'].iloc[-1]],
                                    'sl_side': [sl_trade['side']],
                                    'id': [id],
                                    "sl_id" : [sl_id],
                                    "new_sl_id" : "",
                                    'status' : "starting",
                                    "actual_pnl" : "",
                                    'sl_version' : "sl_mid",
                                    "sym" : symbol,
                                    "sl_max_ref" : float(0),
                                    "sl_mid_ref" : float(0)
                                    })
                    
                                # pprint.pprint(df_trade_row)
                                df_trade_row.set_index('symbol', inplace=True)
                                # pprint.pprint(f'index is ok')
                                # df_trade_row['sl_triggerPrice'] = df_trade_row['sl_triggerPrice'].apply(pd.to_numeric)
                                df_open_trade_info = pd.concat([df_open_trade_info, df_trade_row])
                                # pprint.pprint(df_open_trade_info)
                                nbr_open_trade += 1
                                trade_nb += 1 

                                await refresh_balance()

                    elif len(response_open_ord) == 1 and response_open_ord['id'] != sl_id :


                            alert = {'alert': (f'!!! WARNING {symbol} OUT OF DF')}
                            alert_data = pd.DataFrame(alert, index=[f'ULTIME WARNING {alertnbr} open10 {symbol}'])
                            alert_df = pd.concat([alert_df, alert_data])
                            alertnbr += 1

            elif top_10_values[symbol][1] not in df_open_trade_info.index and data8[symbol + ' Tradable'].iloc[-1] == 'open_short':

                # pprint.pprint(f'tentative data8 pour {symbol}')
            
                try :

                    trade = {
                        'symbol': top_10_values[symbol][1],
                        'side': 'open_short',
                        'size': exchange.amount_to_precision(symbol, round(balance * (0.9/nbr_max_trade), 2) / fulldata[symbol + ' last'].iloc[-1]),
                        'params' : {
                            "marginCoin": "USDT",
                            'side': 'open_short',
                            'force': "post_only",
                            "leverage": "1"}
                        }
                    
                    sl_trade = {
                        'symbol': top_10_values[symbol][1],
                        'side': 'close_short',
                        'size': exchange.amount_to_precision(symbol, round(balance * (0.9/nbr_max_trade), 2) / fulldata[symbol + ' last'].iloc[-1]),
                        "marginCoin": "USDT",
                        "triggerType":"market_price",
                        "reduceOnly" : True,
                        "leverage": "1",
                        "planType" : "track_plan",
                        'side': 'close_short',
                        "timeInForce":"normal",
                        "rangeRate" : 0.2,
                        }
                        
                
                except Exception as e:
                                     
                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} open6 {symbol}'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1
                    continue

                
                id = None
                sl_id = None
                response_create_sl = None
                response_open_ord = None
                create_ord = None

                try :
                    
                    response_create_sl = await exchange.privateMixPostPlanPlaceTrailStop(sl_trade)
                
                    await asyncio.sleep(0.01)

                except Exception as e:

                    alert = {'alert': str(e)}
                    alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} open7 {symbol}'])
                    alert_df = pd.concat([alert_df, alert_data])
                    alertnbr += 1
                    continue

                if response_create_sl ['msg'] == 'success' and 'orderId' in response_create_sl['data']:
                        
                    sl_id = response_create_sl['data']['orderId']
                        
                    await asyncio.sleep(0.01)

                    params = {"stop" : True, "planType" : "track_plan"}
                    response_open_ord = await exchange.fetch_open_orders(symbol, params= params)
                    await asyncio.sleep(0.01)
                    # response_open_ord.extend(await exchange.fetch_open_orders(symbol))
                    # await asyncio.sleep(0.01)

                    if len(response_open_ord) == 1 and any("id" in resp and resp["id"] == sl_id for resp in response_open_ord) : 

                        try :
                    
                            create_ord= await exchange.create_market_order(trade['symbol'], trade['side'], trade['size'], trade['params'])
                
                            await asyncio.sleep(0.01)

                        except Exception as e:
                                     
                            alert = {'alert': str(e)}
                            alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} open8 {symbol}'])
                            alert_df = pd.concat([alert_df, alert_data])
                            alertnbr += 1

                            try :

                                params = {"stop" : True, "planType" : "track_plan"}
                                await exchange.cancel_order(sl_id, symbol, params= params)
                                # await exchange.cancel_order(sl_id, symbol)

                            except Exception as e:

                                alert = {'alert': str(e)}
                                alert_data = pd.DataFrame(alert, index=[f'alert_nbr {alertnbr} open9 {symbol}'])
                                alert_df = pd.concat([alert_df, alert_data])
                                alertnbr += 1

                        if create_ord is not None :
                            
                            if "id" in create_ord : 
                        
                                id = create_ord['id']

                                await asyncio.sleep(0.005)

                                df_trade_row = pd.DataFrame({
                                    'symbol': [trade['symbol']],
                                    'size' : [float(trade['size'])],
                                    'side': [trade['side']],
                                    'opening_price': [fulldata[symbol + ' last'].iloc[-1]],
                                    'sl_side': [sl_trade['side']],
                                    'id': [id],
                                    "sl_id" : [sl_id],
                                    "new_sl_id" : "",
                                    'status' : "starting",
                                    "actual_pnl" : "",
                                    'sl_version' : "sl_mid",
                                    "sym" : symbol,
                                    "sl_max_ref" : float(10000000),
                                    "sl_mid_ref" : float(10000000)
                                    })
                    
                                # pprint.pprint(df_trade_row)
                                df_trade_row.set_index('symbol', inplace=True)
                                # pprint.pprint(f'index is ok')
                                # df_trade_row['sl_triggerPrice'] = df_trade_row['sl_triggerPrice'].apply(pd.to_numeric)
                                df_open_trade_info = pd.concat([df_open_trade_info, df_trade_row])
                                # pprint.pprint(df_open_trade_info)
                                nbr_open_trade += 1
                                trade_nb += 1 

                                await refresh_balance()

                    elif len(response_open_ord) == 1 and response_open_ord['id'] != sl_id :


                            alert = {'alert': (f'!!! WARNING {symbol} OUT OF DF')}
                            alert_data = pd.DataFrame(alert, index=[f'ULTIME WARNING {alertnbr} open10 {symbol}'])
                            alert_df = pd.concat([alert_df, alert_data])
                            alertnbr += 1

# %%
# PARAMETRAGE

nbr_max_trade = 40
time_to_fill = 45
min_occur = 3
div_min_top = 60000
trail_stop = 0.001

wind_Var_Price = 3
wind_EMA1 = 4
wind_Var_EMA1 = 3
wind_EMA2 = 7
wind_EMA3 = 14
wind_Var_EMA2 = 4
wind_Div_Price_EMA1 = 4
wind_Div_EMA1_2 = 6
wind_Div_Moy_Price_EMA1 = 2
wind_Div_Moy_EMA1_2 = 2

occur_wind = 20

trade_nb = 0
nbr_open_trade = 0
alertnbr = 1

rangeRate_max = 0.3
rangeRate_mid = 0.25
rangeRate_low = 0.2
rangeRate_critical = 0.05
rangeRate_rush = 0.03

# INITIALISATION DES DATAFRAMES

data1 = pd.DataFrame()
data2 = pd.DataFrame()
data3 = pd.DataFrame()
data4 = pd.DataFrame()
data5 = pd.DataFrame()
data6 = pd.DataFrame()
data7 = pd.DataFrame()
data8 = pd.DataFrame()
last_20 = pd.DataFrame()
alert_df = pd.DataFrame()
fulldata = pd.DataFrame()
df_open_trade_info = pd.DataFrame()
df_closed_trade_info = pd.DataFrame()

# %%
async def main():

    global wind_Var_Price 
    global wind_EMA1 
    global wind_Var_EMA1
    global wind_EMA2
    global wind_EMA3
    global wind_Var_EMA2
    global wind_Div_Price_EMA1
    global wind_Div_EMA1_2
    global wind_Div_Moy_Price_EMA1
    global wind_Div_Moy_EMA1_2

    global occur_wind
    global min_occur
    global div_min_top
    global trail_stop
    global nbr_max_trade
    global nbr_open_trade
    global trade_nb
    global alert_df
    global alertnbr
    global time_to_fill

    global last_20

    global data1
    global data2
    global data3 
    global data4 
    global data5
    global data6
    global data7
    global data8
    global fulldata
    global df_open_trade_info
    global df_closed_trade_info

    global rangeRate_max
    global rangeRate_mid
    global rangeRate_low
    global rangeRate_critical
    global rangeRate_rush

    while True:

        try:

            await refresh_balance()
            display(last_20.index[-2:])
            display(df_closed_trade_info.tail(5))
            display(df_open_trade_info)
            display(f'Balance is {balance}')
            display(f'Open PNL is {open_PNL}')
            display(f'nbr open trade is {nbr_open_trade}')
            display(alert_df.tail(5))
            await config_strikerV3()
            await asyncio.sleep(0.005)
            await cleaner()
            await asyncio.sleep(0.005)
            await live_prices()
            await asyncio.sleep(0.005)
            await indicators_calculation()
            await asyncio.sleep(0.005)
            await sl_loader()
            await asyncio.sleep(0.005)
            await cleaner()
            await asyncio.sleep(0.005)
            await trade_opener()
            await asyncio.sleep(0.005)

        except KeyboardInterrupt:

            display(f'Interuption du programme ')
            await exchange.close()
            break

        clear_output(wait=True)

        await asyncio.sleep(0.001)

await main()
# Out:
# DatetimeIndex(['2023-12-22 13:46:19', '2023-12-22 13:46:22'], dtype='datetime64[ns]', freq=None)
#                 size        side  opening_price      sl_side  \
# symbol
# API3USDT_UMCBL   4.8  open_short         1.8140  close_short
# C98USDT_UMCBL   35.8  open_short         0.2446  close_short
#
#                                  id                sl_id            new_sl_id  \
# symbol
# API3USDT_UMCBL  1122072500780019716  1122073294998675458  1122073294998675458
# C98USDT_UMCBL   1122072578160734210  1122073365580419073  1122073365580419073
#
#                status actual_pnl sl_version             sym  sl_max_ref  \
# symbol
# API3USDT_UMCBL  close     0.0432    sl_rush  API3/USDT:USDT      1.8110
# C98USDT_UMCBL   close    0.03938    sl_rush   C98/USDT:USDT      0.2446
#
#                   sl_mid_ref
# symbol
# API3USDT_UMCBL  1.000000e+07
# C98USDT_UMCBL   2.442000e-01
#                     size        side  opening_price      sl_side  \
# symbol
# BNBUSDT_UMCBL       0.03   open_long     268.920000   close_long
# UMAUSDT_UMCBL       3.90  open_short       2.195000  close_short
# LTCUSDT_UMCBL       0.10  open_short      71.320000  close_short
# FLOWUSDT_UMCBL      9.70  open_short       0.895000  close_short
# XTZUSDT_UMCBL       8.00  open_short       0.999000  close_short
# ONEUSDT_UMCBL     521.00  open_short       0.016830  close_short
# MANAUSDT_UMCBL     16.00  open_short       0.515900  close_short
# ARKMUSDT_UMCBL     13.00  open_short       0.661100  close_short
# SLPUSDT_UMCBL    2854.00  open_short       0.003072  close_short
# LINAUSDT_UMCBL    832.00  open_short       0.010540  close_short
# ICXUSDT_UMCBL      33.00  open_short       0.261700  close_short
# REEFUSDT_UMCBL   4158.00  open_short       0.002109  close_short
# LOOKSUSDT_UMCBL    97.60  open_short       0.089800  close_short
# CELRUSDT_UMCBL    420.00  open_short       0.020870  close_short
# AUDIOUSDT_UMCBL    38.00  open_short       0.228100  close_short
# TRXUSDT_UMCBL      84.00  open_short       0.104320  close_short
# RSRUSDT_UMCBL    3023.00  open_short       0.002901  close_short
#
#                                   id                sl_id  \
# symbol
# BNBUSDT_UMCBL    1122072478722174986  1122072841690877954
# UMAUSDT_UMCBL    1122072712646897667  1122073787024089089
# LTCUSDT_UMCBL    1122072806330871820  1122073791994339329
# FLOWUSDT_UMCBL   1122072855840436231  1122072939950841857
# XTZUSDT_UMCBL    1122072957082546179  1122073857517756418
# ONEUSDT_UMCBL    1122073303414616066  1122073747887034371
# MANAUSDT_UMCBL   1122073331117993985  1122073473147543553
# ARKMUSDT_UMCBL   1122073401011875841  1122073528038395905
# SLPUSDT_UMCBL    1122073430569136132  1122073752886644737
# LINAUSDT_UMCBL   1122073481680924680  1122073897808236548
# ICXUSDT_UMCBL    1122073498747547649  1122073619121905665
# REEFUSDT_UMCBL   1122073571380310017  1122073685526122497
# LOOKSUSDT_UMCBL  1122073644243759120  1122073759765303297
# CELRUSDT_UMCBL   1122073659615883267  1122073902619103233
# AUDIOUSDT_UMCBL  1122073768273522690  1122073818951127041
# TRXUSDT_UMCBL    1122073800401891329  1122073837049552897
# RSRUSDT_UMCBL    1122073865904336902  1122073907522244609
#
#                            new_sl_id status actual_pnl   sl_version  \
# symbol
# BNBUSDT_UMCBL    1122072841690877954   open    -0.0063  sl_critical
# UMAUSDT_UMCBL    1122073787024089089   open    -0.0039  sl_critical
# LTCUSDT_UMCBL    1122073791994339329   open      0.002       sl_max
# FLOWUSDT_UMCBL   1122072939950841857   open     0.0291       sl_max
# XTZUSDT_UMCBL    1122073857517756418   open    -0.0016  sl_critical
# ONEUSDT_UMCBL    1122073747887034371   open   -0.01042  sl_critical
# MANAUSDT_UMCBL   1122073473147543553   open     -0.004  sl_critical
# ARKMUSDT_UMCBL   1122073528038395905   open    -0.0091  sl_critical
# SLPUSDT_UMCBL    1122073752886644737   open   -0.02854  sl_critical
# LINAUSDT_UMCBL   1122073897808236548   open   -0.00832  sl_critical
# ICXUSDT_UMCBL    1122073619121905665   open     0.0033  sl_critical
# REEFUSDT_UMCBL   1122073685526122497   open   0.004158       sl_max
# LOOKSUSDT_UMCBL  1122073759765303297   open   -0.00976  sl_critical
# CELRUSDT_UMCBL   1122073902619103233   open    -0.0042  sl_critical
# AUDIOUSDT_UMCBL  1122073818951127041   open    -0.0114  sl_critical
# TRXUSDT_UMCBL    1122073837049552897   open        0.0  sl_critical
# RSRUSDT_UMCBL    1122073907522244609   open        0.0       sl_max
#
#                              sym  sl_max_ref    sl_mid_ref
# symbol
# BNBUSDT_UMCBL      BNB/USDT:USDT  268.920000  2.688400e+02
# UMAUSDT_UMCBL      UMA/USDT:USDT    2.193000  1.000000e+07
# LTCUSDT_UMCBL      LTC/USDT:USDT   71.310000  1.000000e+07
# FLOWUSDT_UMCBL    FLOW/USDT:USDT    0.895000  1.000000e+07
# XTZUSDT_UMCBL      XTZ/USDT:USDT    0.998000  1.000000e+07
# ONEUSDT_UMCBL      ONE/USDT:USDT    0.016830  1.684000e-02
# MANAUSDT_UMCBL    MANA/USDT:USDT    0.515900  1.000000e+07
# ARKMUSDT_UMCBL    ARKM/USDT:USDT    0.661100  1.000000e+07
# SLPUSDT_UMCBL      SLP/USDT:USDT    0.003070  1.000000e+07
# LINAUSDT_UMCBL    LINA/USDT:USDT    0.010530  1.000000e+07
# ICXUSDT_UMCBL      ICX/USDT:USDT    0.261400  1.000000e+07
# REEFUSDT_UMCBL    REEF/USDT:USDT    0.002110  1.000000e+07
# LOOKSUSDT_UMCBL  LOOKS/USDT:USDT    0.089900  8.990000e-02
# CELRUSDT_UMCBL    CELR/USDT:USDT    0.020840  2.087000e-02
# AUDIOUSDT_UMCBL  AUDIO/USDT:USDT    0.227700  1.000000e+07
# TRXUSDT_UMCBL      TRX/USDT:USDT    0.104320  1.000000e+07
# RSRUSDT_UMCBL      RSR/USDT:USDT    0.002904  1.000000e+07
# 'Balance is 389.93977315'
# 'Open PNL is -0.096083'
# 'nbr open trade is 17'
#                                                                              alert
# alert_nbr 1 open7 ZZZ/USDT:USDT  bitget {"code":"22004","msg":"This symbol ZZZU...
# 'ARKMUSDT_UMCBL sl version set to mid'
# 'ARKMUSDT_UMCBL sl version set to critical'
# 'RSRUSDT_UMCBL sl version set to mid'
# 'RSRUSDT_UMCBL sl version set to critical'
# 2023-12-22 13:46:29
# open_short    2
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[92], line 82
#      78         clear_output(wait=True)
#      80         await asyncio.sleep(0.001)
# ---> 82 await main()
#
# Cell In[92], line 64, in main()
#      62 await asyncio.sleep(0.005)
#      63 await indicators_calculation()
# ---> 64 await asyncio.sleep(0.005)
#      65 await sl_loader()
#      66 await asyncio.sleep(0.005)
#
# File c:\Python312\Lib\asyncio\tasks.py:655, in sleep(delay, result)
#     651 h = loop.call_later(delay,
#     652                     futures._set_result_unless_cancelled,
#     653                     future, result)
#     654 try:
# --> 655     return await future
#     656 finally:
#     657     h.cancel()
#
# CancelledError:

# %%
display(fulldata.columns)
# Out:
# Index(['10000LADYS/USDT:USDT Condition',
#        '10000LADYS/USDT:USDT Diff Carre EMA_1_2',
#        '10000LADYS/USDT:USDT Diff Carre Price_EMA_1',
#        '10000LADYS/USDT:USDT Divergence EMA_1_2',
#        '10000LADYS/USDT:USDT Divergence Moyen EMA_1_2',
#        '10000LADYS/USDT:USDT Divergence Moyen Price_EMA_1',
#        '10000LADYS/USDT:USDT Divergence Price_EMA_1',
#        '10000LADYS/USDT:USDT EMA_1', '10000LADYS/USDT:USDT EMA_2',
#        '10000LADYS/USDT:USDT EMA_3',
#        ...
#        'ZZZ/USDT:USDT Occur', 'ZZZ/USDT:USDT Top_10', 'ZZZ/USDT:USDT Tradable',
#        'ZZZ/USDT:USDT Var Carre Last Price', 'ZZZ/USDT:USDT Var EMA_1',
#        'ZZZ/USDT:USDT Var EMA_2', 'ZZZ/USDT:USDT Var Last Price',
#        'ZZZ/USDT:USDT ask', 'ZZZ/USDT:USDT bid', 'ZZZ/USDT:USDT last'],
#       dtype='object', length=4060)

# %%
display(alert_df)
# Out:
#                                                                  alert
# Not alert_nbr 1 sl3  bitget {"code":"43033","msg":"Trailing order d...

# %%
display(df_closed_trade_info)
# Out:
#                     size        side  opening_price      sl_side  \
# symbol
# TONUSDT_UMCBL        4.3  open_short       2.193000  close_short
# AGIXUSDT_UMCBL      29.0  open_short       0.318600  close_short
# SNXUSDT_UMCBL        2.5  open_short       3.757000  close_short
# ONEUSDT_UMCBL      621.0  open_short       0.015230  close_short
# FLOWUSDT_UMCBL      11.3  open_short       0.835000  close_short
# ...                  ...         ...            ...          ...
# DENTUSDT_UMCBL    8859.0  open_short       0.001061  close_short
# GTCUSDT_UMCBL        7.7  open_short       1.212000  close_short
# SFPUSDT_UMCBL       13.0  open_short       0.721900  close_short
# PEOPLEUSDT_UMCBL   640.0  open_short       0.013120  close_short
# RADUSDT_UMCBL        5.7  open_short       1.624000  close_short
#
#                                    id                sl_id  \
# symbol
# TONUSDT_UMCBL     1121468522144870401  1121468555760046080
# AGIXUSDT_UMCBL    1121468454767570944  1121468575137734657
# SNXUSDT_UMCBL     1121468598246322191  1121468633111400449
# ONEUSDT_UMCBL     1121469419793035265  1121469461801017345
# FLOWUSDT_UMCBL    1121470261145251843  1121470299080560641
# ...                               ...                  ...
# DENTUSDT_UMCBL    1121479651487264769  1121479684024504321
# GTCUSDT_UMCBL     1121480049094701059  1121480093069811713
# SFPUSDT_UMCBL     1121479038837862401  1121480208765489153
# PEOPLEUSDT_UMCBL  1121479720785555459  1121479760616689665
# RADUSDT_UMCBL     1121479787936362497  1121479821111140353
#
#                             new_sl_id status actual_pnl   sl_version  \
# symbol
# TONUSDT_UMCBL     1121468555760046080  close    -0.0086  sl_critical
# AGIXUSDT_UMCBL    1121468575137734657  close    -0.0094  sl_critical
# SNXUSDT_UMCBL     1121468633111400449  close    -0.0175  sl_critical
# ONEUSDT_UMCBL     1121469461801017345  close   -0.00621  sl_critical
# FLOWUSDT_UMCBL    1121470299080560641  close        0.0  sl_critical
# ...                               ...    ...        ...          ...
# DENTUSDT_UMCBL    1121479684024504321  close        0.0  sl_critical
# GTCUSDT_UMCBL     1121480093069811713  close        0.0  sl_critical
# SFPUSDT_UMCBL     1121480208765489153  close        0.0  sl_critical
# PEOPLEUSDT_UMCBL  1121479760616689665  close    -0.0128  sl_critical
# RADUSDT_UMCBL     1121479821111140353  close    -0.0057  sl_critical
#
#                                sym    sl_max_ref    sl_mid_ref
# symbol
# TONUSDT_UMCBL        TON/USDT:USDT  2.193000e+00  1.000000e+07
# AGIXUSDT_UMCBL      AGIX/USDT:USDT  3.185000e-01  3.187000e-01
# SNXUSDT_UMCBL        SNX/USDT:USDT  1.000000e+07  3.762000e+00
# ONEUSDT_UMCBL        ONE/USDT:USDT  1.522000e-02  1.000000e+07
# FLOWUSDT_UMCBL      FLOW/USDT:USDT  8.350000e-01  1.000000e+07
# ...                            ...           ...           ...
# DENTUSDT_UMCBL      DENT/USDT:USDT  1.062000e-03  1.000000e+07
# GTCUSDT_UMCBL        GTC/USDT:USDT  1.211000e+00  1.000000e+07
# SFPUSDT_UMCBL        SFP/USDT:USDT  7.211000e-01  7.217000e-01
# PEOPLEUSDT_UMCBL  PEOPLE/USDT:USDT  1.311000e-02  1.000000e+07
# RADUSDT_UMCBL        RAD/USDT:USDT  1.624000e+00  1.000000e+07
#
# [66 rows x 13 columns]

# %%
await exchange.fetch_positions(['GMTUSDT_UMCBL'])
# Out:
# [{'info': {'marginCoin': 'USDT',
#    'symbol': 'GMTUSDT_UMCBL',
#    'holdSide': 'short',
#    'openDelegateCount': '0',
#    'margin': '9.888',
#    'available': '40',
#    'locked': '0',
#    'total': '40',
#    'leverage': '1',
#    'achievedProfits': '0',
#    'averageOpenPrice': '0.2472',
#    'marginMode': 'crossed',
#    'holdMode': 'double_hold',
#    'unrealizedPL': '0.02',
#    'liquidationPrice': '2.330873359048',
#    'keepMarginRate': '0.015',
#    'marketPrice': '0.2467',
#    'marginRatio': '0.001549261666',
#    'autoMargin': 'off',
#    'cTime': '1703013582009',
#    'uTime': '1703013582009'},
#   'id': None,
#   'symbol': 'GMT/USDT:USDT',
#   'notional': 9.868,
#   'marginMode': 'cross',
#   'liquidationPrice': 2.330873359048,
#   'entryPrice': 0.2472,
#   'unrealizedPnl': 0.02,
#   'realizedPnl': None,
#   'percentage': 0.2,
#   'contracts': 40.0,
#   'contractSize': 1,
#   'markPrice': 0.2467,
#   'lastPrice': None,
#   'side': 'short',
#   'hedged': True,
#   'timestamp': 1703013582009,
#   'datetime': '2023-12-19T19:19:42.009Z',
#   'lastUpdateTimestamp': None,
#   'maintenanceMargin': 0.1539408,
#   'maintenanceMarginPercentage': 0.015,
#   'collateral': None,
#   'initialMargin': 9.888,
#   'initialMarginPercentage': 1.0020267531414673,
#   'leverage': 1.0,
#   'marginRatio': None,
#   'stopLossPrice': None,
#   'takeProfitPrice': None}]

# %%
params = {"stop" : True}
await exchange.fetch_open_orders('HOTUSDT_UMCBL', params= params)
# Out:
# [{'info': {'orderId': '1121295780969783297',
#    'clientOid': '1121295780969783296',
#    'symbol': 'HOTUSDT_UMCBL',
#    'marginCoin': 'USDT',
#    'size': '4624',
#    'executePrice': '0',
#    'triggerPrice': '0',
#    'status': 'not_trigger',
#    'orderType': 'market',
#    'planType': 'track_plan',
#    'side': 'close_short',
#    'triggerType': 'market_price',
#    'presetTakeProfitPrice': '0',
#    'presetTakeLossPrice': '0',
#    'rangeRate': '0.3',
#    'enterPointSource': 'API',
#    'tradeSide': 'close_short',
#    'holdMode': 'double_hold',
#    'reduceOnly': True,
#    'cTime': '1703063667528',
#    'uTime': None},
#   'id': '1121295780969783297',
#   'clientOrderId': '1121295780969783296',
#   'timestamp': 1703063667528,
#   'datetime': '2023-12-20T09:14:27.528Z',
#   'lastTradeTimestamp': None,
#   'lastUpdateTimestamp': None,
#   'symbol': 'HOT/USDT:USDT',
#   'type': 'market',
#   'timeInForce': 'IOC',
#   'postOnly': None,
#   'side': 'buy',
#   'price': None,
#   'stopPrice': 0.0,
#   'triggerPrice': 0.0,
#   'average': None,
#   'cost': None,
#   'amount': 4624.0,
#   'filled': None,
#   'remaining': None,
#   'status': 'open',
#   'fee': None,
#   'trades': [],
#   'fees': [],
#   'reduceOnly': None,
#   'takeProfitPrice': None,
#   'stopLossPrice': None}]

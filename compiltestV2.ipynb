# %%
import ta
import ccxt
import time
import pprint
import pandas as pd
import SecretConfig
from IPython.display import clear_output

# Définir l'échange
exchange = ccxt.bitget({
    "apiKey":SecretConfig.APIKey,
    "secret":SecretConfig.SecretKey,
    'password': SecretConfig.Passphrase,
    "options": {'defaultType': 'swap', 'adjustForTimeDifference' : True},
    "timeout": 60000,
    "enableRateLimit": True,
})

# %%
# Initialiser un DataFrame vide pour stocker les données roulantes
full_rolling_dataframe = pd.DataFrame()

# Définir une fonction pour récupérer et traiter les données
def fetch_data():
    global full_rolling_dataframe
    while True:
        # Récupérer les données des contrats à terme
        futures_tickers = exchange.fetch_tickers(params={'type': 'swap'})
        tickers_name_list = futures_tickers.keys()

        # Initialiser un dictionnaire pour stocker les nouvelles données
        data = {}

        # Parcourir chaque contrat à terme
        for ticker in tickers_name_list:

            # Récupérer les informations pertinentes pour chaque contrat à terme
            ticker_name = ticker.split('/')[0]
            data[ticker_name + ' Last Price'] = futures_tickers.get(ticker, {}).get('info', {}).get('last')
            data[ticker_name + ' EMA_1'] = None
            data[ticker_name + ' Var EMA_1'] = None
            data[ticker_name + ' EMA_2'] = None
            data[ticker_name + ' Ecart Carre EMA_1_2'] = None
            data[ticker_name + ' Divergence EMA_1_2'] = None
            data[ticker_name + ' Divergence Moyen Wind1'] = None
            


        # Convertir le dictionnaire en DataFrame
        data['Timestamp'] = futures_tickers.get(ticker, {}).get('timestamp')
        new_data_df = pd.DataFrame([data])

        # Convertir les colonnes en numérique et définir 'Timestamp' comme index
        new_data_df = new_data_df.apply(pd.to_numeric)
        new_data_df['Timestamp'] = pd.to_datetime(new_data_df['Timestamp'], unit='ms')
        new_data_df['Timestamp'] = new_data_df['Timestamp'].dt.round('10L')
        new_data_df = new_data_df.set_index('Timestamp')

        # Ajouter les nouvelles données au DataFrame roulant
        full_rolling_dataframe = pd.concat([full_rolling_dataframe, new_data_df])

        wind1 = 3
        wind2 = 12

        # Calculer les indicateurs techniques
        for ticker in tickers_name_list:
            ticker_name = ticker.split('/')[0]
            full_rolling_dataframe[ticker_name + ' EMA_1'] = ta.trend.ema_indicator(full_rolling_dataframe[ticker_name + ' Last Price'], window= wind1)
            if len(full_rolling_dataframe) >= wind1:
                full_rolling_dataframe[ticker_name + ' Var EMA_1'] = ((full_rolling_dataframe[ticker_name + ' EMA_1'] - full_rolling_dataframe[ticker_name + ' EMA_1'].iloc[- wind1] ) 
                                                                      / full_rolling_dataframe[ticker_name + ' EMA_1'].iloc[- wind1]) * 100
            else:
                full_rolling_dataframe[ticker_name + ' Var EMA_1']  = None
            full_rolling_dataframe[ticker_name + ' EMA_2'] = ta.trend.ema_indicator(full_rolling_dataframe[ticker_name + ' Last Price'], window= wind2)
            full_rolling_dataframe[ticker_name + ' Diff EMA_1_2'] = full_rolling_dataframe[ticker_name + ' EMA_1'] - full_rolling_dataframe[ticker_name + ' EMA_2']
            full_rolling_dataframe[ticker_name + ' Divergence EMA_1_2']= full_rolling_dataframe[ticker_name + ' Diff EMA_1_2'].pct_change(fill_method=None)
            full_rolling_dataframe[ticker_name + ' Divergence Moyen Wind1'] = ta.trend.ema_indicator(full_rolling_dataframe[ticker_name + ' Divergence EMA_1_2'], window= wind1)
            full_rolling_dataframe = full_rolling_dataframe.copy()

        # Convertir en données numériques
        full_rolling_dataframe = full_rolling_dataframe.apply(pd.to_numeric)

        # Limiter le DataFrame roulant aux 600 dernières périodes
        full_rolling_dataframe = full_rolling_dataframe.tail(50)

        # Sélectionnez les colonnes de variation
        cols_variation = [col for col in full_rolling_dataframe.columns if ' Divergence Moyen Wind1' in col]

        # Obtenez la dernière ligne du DataFrame
        last_row = full_rolling_dataframe.iloc[-1]

        # Créez une série avec seulement les colonnes de variation de la dernière ligne
        last_row_variation = last_row[cols_variation]

        # Obtenez la valeur absolue des variations
        last_row_variation_abs = last_row_variation.abs()

        # Obtenez les 10 plus grandes variations
        top_10_variations = last_row_variation_abs.nlargest(10)

        # Créez un nouveau DataFrame avec seulement les 10 plus grandes variations
        df_top_10 = full_rolling_dataframe[top_10_variations.index]
        df_top_10 = df_top_10.tail(1)


        # Afficher les 10 dernières lignes du DataFrame
        clear_output(wait=True)
        display(full_rolling_dataframe.tail(20))
        # print(df_top_10)
        # pprint.pprint(full_rolling_dataframe[ticker_name + ' ATR'])
        # pprint.pprint(full_rolling_dataframe[ticker_name + ' ATR Change'])
        # pprint.pprint(full_rolling_dataframe)

        # Attendre 1 seconde avant de récupérer à nouveau les données
        time.sleep(0.5)



fetch_data()
# Out:
#                          BTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:44:59.890                         NaN
#
#                          ETH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:44:59.890                         NaN
#
#                          XRP Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:44:59.890                         NaN
#
#                          EOS Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:44:59.890                         NaN
#
#                          BCH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:44:59.890                         NaN
#
#                          LTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:44:59.890                         NaN
#
#                          ADA Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:44:59.890                         NaN
#
#                          ETC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:44:59.890                         NaN
#
#                          LINK Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:44:59.890                          NaN
#
#                          TRX Divergence Moyen Wind1
# Timestamp
# 2023-11-12 20:44:59.890                         NaN
#                          BTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:01.820                         NaN
#
#                          ETH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:01.820                         NaN
#
#                          XRP Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:01.820                         NaN
#
#                          EOS Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:01.820                         NaN
#
#                          BCH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:01.820                         NaN
#
#                          LTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:01.820                         NaN
#
#                          ADA Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:01.820                         NaN
#
#                          ETC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:01.820                         NaN
#
#                          LINK Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:01.820                          NaN
#
#                          TRX Divergence Moyen Wind1
# Timestamp
# 2023-11-12 20:45:01.820                         NaN
#                          BTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:03.780                         NaN
#
#                          ETH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:03.780                         NaN
#
#                          XRP Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:03.780                         NaN
#
#                          EOS Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:03.780                         NaN
#
#                          BCH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:03.780                         NaN
#
#                          LTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:03.780                         NaN
#
#                          ADA Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:03.780                         NaN
#
#                          ETC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:03.780                         NaN
#
#                          LINK Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:03.780                          NaN
#
#                          TRX Divergence Moyen Wind1
# Timestamp
# 2023-11-12 20:45:03.780                         NaN
#                          BTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:05.640                         NaN
#
#                          ETH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:05.640                         NaN
#
#                          XRP Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:05.640                         NaN
#
#                          EOS Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:05.640                         NaN
#
#                          BCH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:05.640                         NaN
#
#                          LTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:05.640                         NaN
#
#                          ADA Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:05.640                         NaN
#
#                          ETC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:05.640                         NaN
#
#                          LINK Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:05.640                          NaN
#
#                          TRX Divergence Moyen Wind1
# Timestamp
# 2023-11-12 20:45:05.640                         NaN
#                          BTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:07.430                         NaN
#
#                          ETH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:07.430                         NaN
#
#                          XRP Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:07.430                         NaN
#
#                          EOS Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:07.430                         NaN
#
#                          BCH Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:07.430                         NaN
#
#                          LTC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:07.430                         NaN
#
#                          ADA Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:07.430                         NaN
#
#                          ETC Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:07.430                         NaN
#
#                          LINK Divergence Moyen Wind1  \
# Timestamp
# 2023-11-12 20:45:07.430                          NaN
#
#                          TRX Divergence Moyen Wind1
# Timestamp
# 2023-11-12 20:45:07.430                         NaN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\IEL\Desktop\BitgetBotV1\compiltestV2.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=90'>91</a>         # pprint.pprint(full_rolling_dataframe[ticker_name + ' ATR'])
#      <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=91'>92</a>         # pprint.pprint(full_rolling_dataframe[ticker_name + ' ATR Change'])
#      <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=92'>93</a>         # pprint.pprint(full_rolling_dataframe)
#      <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=93'>94</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=94'>95</a>         # Attendre 1 seconde avant de récupérer à nouveau les données
#      <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=95'>96</a>         time.sleep(0.5)
# --> <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=99'>100</a> fetch_data()
#
# c:\Users\IEL\Desktop\BitgetBotV1\compiltestV2.ipynb Cell 2 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> global full_rolling_dataframe
#       <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> while True:
#       <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a>     # Récupérer les données des contrats à terme
# ----> <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>     futures_tickers = exchange.fetch_tickers(params={'type': 'swap'})
#      <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a>     tickers_name_list = futures_tickers.keys()
#      <a href='vscode-notebook-cell:/c%3A/Users/IEL/Desktop/BitgetBotV1/compiltestV2.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>     # Initialiser un dictionnaire pour stocker les nouvelles données
#
# File c:\Python312\Lib\site-packages\ccxt\bitget.py:2194, in bitget.fetch_tickers(self, symbols, params)
#    2192     response = self.publicSpotGetMarketTickers(extended)
#    2193 else:
# -> 2194     response = self.publicMixGetMarketTickers(extended)
#    2195 #
#    2196 # spot
#    2197 #
#    (...)
#    2239 #     }
#    2240 #
#    2241 data = self.safe_value(response, 'data')
#
# File c:\Python312\Lib\site-packages\ccxt\base\types.py:28, in Entry.__init__.<locals>.unbound_method(_self, params)
#      27 def unbound_method(_self, params={}):
# ---> 28     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File c:\Python312\Lib\site-packages\ccxt\base\exchange.py:3196, in Exchange.request(self, path, api, method, params, headers, body, config)
#    3195 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Optional[Any] = None, body: Optional[Any] = None, config={}):
# -> 3196     return self.fetch2(path, api, method, params, headers, body, config)
#
# File c:\Python312\Lib\site-packages\ccxt\base\exchange.py:3193, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    3191 self.last_request_body = request['body']
#    3192 self.last_request_url = request['url']
# -> 3193 return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#
# File c:\Python312\Lib\site-packages\ccxt\base\exchange.py:588, in Exchange.fetch(self, url, method, headers, body)
#     586 json_response = None
#     587 try:
# --> 588     response = self.session.request(
#     589         method,
#     590         url,
#     591         data=body,
#     592         headers=request_headers,
#     593         timeout=int(self.timeout / 1000),
#     594         proxies=proxies,
#     595         verify=self.verify and self.validateServerSsl
#     596     )
#     597     # does not try to detect encoding
#     598     response.encoding = 'utf-8'
#
# File c:\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Python312\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Python312\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File c:\Python312\Lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Python312\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File c:\Python312\Lib\http\client.py:1411, in HTTPConnection.getresponse(self)
#    1409 try:
#    1410     try:
# -> 1411         response.begin()
#    1412     except ConnectionError:
#    1413         self.close()
#
# File c:\Python312\Lib\http\client.py:324, in HTTPResponse.begin(self)
#     322 # read until we get a non-100 response
#     323 while True:
# --> 324     version, status, reason = self._read_status()
#     325     if status != CONTINUE:
#     326         break
#
# File c:\Python312\Lib\http\client.py:285, in HTTPResponse._read_status(self)
#     284 def _read_status(self):
# --> 285     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     286     if len(line) > _MAXLINE:
#     287         raise LineTooLong("status line")
#
# File c:\Python312\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File c:\Python312\Lib\ssl.py:1249, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1245     if flags != 0:
#    1246         raise ValueError(
#    1247           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1248           self.__class__)
# -> 1249     return self.read(nbytes, buffer)
#    1250 else:
#    1251     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Python312\Lib\ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
dir(ta)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'add_all_ta_features',
#  'add_momentum_ta',
#  'add_others_ta',
#  'add_trend_ta',
#  'add_volatility_ta',
#  'add_volume_ta',
#  'momentum',
#  'others',
#  'trend',
#  'utils',
#  'volatility',
#  'volume',
#  'wrapper']

# %%
import ccxt
import time
import pprint
import pandas as pd
import SecretConfig
import ta
from IPython.display import clear_output
import asyncio

# %%
data = pd.read_csv("Backtest_Maxiresult.csv")
datacor = data.corr()
pprint.pprint(datacor)

# %%
data = pd.read_csv("Backtest_Maxiresult.csv")
data_sorted = data.sort_values(by='balance', ascending=False)
pprint.pprint(data_sorted)

# %%
data = pd.read_csv("Backtest_Maxiresult.csv")

data['total_balance'] = data['balance'] + data['unclose_PnL'] + data['frais']
data_sorted = data.sort_values(by='total_balance', ascending=False)
pprint.pprint(data_sorted.head(25))
# Out:
#       Unnamed: 0  wind_Var_Price  wind_EMA1  wind_Var_EMA1  wind_EMA2  \
# 5380           0               3          4              3          9
# 5560           0               3          4              4          9
# 5344           0               3          4              3          9
# 5596           0               3          4              4          9
# 3186           0               3          5              3          9
# 3402           0               3          5              4          9
# 3438           0               3          5              4          9
# 3222           0               3          5              3          9
# 3366           0               3          5              4          8
# 3330           0               3          5              4          8
# 3150           0               3          5              3          8
# 3114           0               3          5              3          8
# ...
